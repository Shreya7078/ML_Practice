# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('data\indian_house_price.csv')
df.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\i'
# <>:1: SyntaxWarning: invalid escape sequence '\i'
# C:\Users\Asus\AppData\Local\Temp\ipykernel_16372\1572362376.py:1: SyntaxWarning: invalid escape sequence '\i'
#   df=pd.read_csv('data\indian_house_price.csv')
#         City  Size_sqft  Bedrooms  Age_years  Floor    Price_INR
# 0  Ahmedabad      853.0         3          9      6    41,89,597
# 1    Chennai     1594.0         2         11      2  1,28,69,986
# 2     Mumbai     2026.0         1          6      1  2,69,22,862
# 3       Pune     1871.0         4         24      1  1,30,26,589
# 4  Hyderabad     1489.0         4          1      2  1,19,05,135

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['City_encoded']=le.fit_transform(df['City'])

# %%
X = df[['Size_sqft', 'Bedrooms', 'Age_years', 'Floor', 'City_encoded']]
y=df['Price_INR']

# %%
X
# Out:
#     Size_sqft  Bedrooms  Age_years  Floor  City_encoded
# 0       853.0         3          9      6             0
# 1      1594.0         2         11      2             2
# 2      2026.0         1          6      1             6
# 3      1871.0         4         24      1             7
# 4      1489.0         4          1      2             4
# 5       989.0         2         21      2             4
# 6      1532.0         3         21      6             0
# 7      1308.0         4         11      4             0
# 8      1507.0         2         28      3             2
# 9      1295.0         1         24      1             6
# 10     2192.0         1         19      5             7
# 11     2060.0         2         23      9             0
# 12     1197.0         2         23      8             3
# 13     1688.0         2         25      2             6
# 14     1124.0         3         12      5             7
# 15     1460.0         1         12      4             1
# 16     1271.0         1         13      7             1
# 17     1849.0         3          4      8             3
# 18     1304.0         3          7      2             0
# 19     1472.0         3         21      1             7
# 20     1967.0         1         26      3             2
# 21     1385.0         3          9      8             3
# 22     2322.0         1          6      1             0
# 23      943.0         3         15      1             0
# 24     2008.0         4         11      9             2
# 25     1403.0         3         27      3             3
# 26     1410.0         3         18      1             4
# 27     1805.0         1         28      6             0
# 28     1594.0         2         16      6             1
# 29     1388.0         2          5      1             7
# 30      603.0         3          3      1             4
# 31      775.0         3         13      9             2
# 32     1948.0         2          0      5             2
# 33     1596.0         2         21      6             0
# 34     1923.0         4         23      2             5
# 35     2415.0         2          1      5             3
# 36     1898.0         3         13      1             3
# 37      701.0         1          8      8             0
# 38     1187.0         2         20      3             5
# 39     1726.0         1         27      1             3
# 40     1047.0         1         14      4             4
# 41     2433.0         3         13      9             5
# 42     2396.0         4          9      4             3
# 43     2212.0         2         10      8             1
# 44     1497.0         2          0      2             3
# 45     2199.0         4          2      1             6
# 46      849.0         2         16      2             7
# 47     1187.0         1         23      5             7
# 48     1480.0         4          6      7             2
# 49     2010.0         1         18      2             7

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          50 non-null     object
#  1   Size_sqft     50 non-null     float64
#  2   Bedrooms      50 non-null     int64
#  3   Age_years     50 non-null     int64
#  4   Floor         50 non-null     int64
#  5   Price_INR     50 non-null     float64
#  6   City_encoded  50 non-null     int64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 2.9+ KB

# %%
df.isnull().sum()
# Out:
# City            0
# Size_sqft       0
# Bedrooms        0
# Age_years       0
# Floor           0
# Price_INR       0
# City_encoded    0
# dtype: int64

# %%
df.head()
# Out:
#         City  Size_sqft  Bedrooms  Age_years  Floor   Price_INR  City_encoded
# 0  Ahmedabad      853.0         3          9      6   4189597.0             0
# 1    Chennai     1594.0         2         11      2  12869986.0             2
# 2     Mumbai     2026.0         1          6      1  26922862.0             6
# 3       Pune     1871.0         4         24      1  13026589.0             7
# 4  Hyderabad     1489.0         4          1      2  11905135.0             4

# %%
df.drop(['City'],axis=1,inplace=True)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=42)

# %%
X_train.shape
# Out:
# (40, 5)

# %%
df.head()
# Out:
#    Size_sqft  Bedrooms  Age_years  Floor   Price_INR  City_encoded
# 0      853.0         3          9      6   4189597.0             0
# 1     1594.0         2         11      2  12869986.0             2
# 2     2026.0         1          6      1  26922862.0             6
# 3     1871.0         4         24      1  13026589.0             7
# 4     1489.0         4          1      2  11905135.0             4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Size_sqft     50 non-null     float64
#  1   Bedrooms      50 non-null     int64
#  2   Age_years     50 non-null     int64
#  3   Floor         50 non-null     int64
#  4   Price_INR     50 non-null     float64
#  5   City_encoded  50 non-null     int64
# dtypes: float64(2), int64(4)
# memory usage: 2.5 KB

# %%
df['Price_INR'] = df['Price_INR'].apply(lambda x: float(str(x).replace(',', '')))

# %%
df.head()
# Out:
#    Size_sqft  Bedrooms  Age_years  Floor   Price_INR  City_encoded
# 0      853.0         3          9      6   4189597.0             0
# 1     1594.0         2         11      2  12869986.0             2
# 2     2026.0         1          6      1  26922862.0             6
# 3     1871.0         4         24      1  13026589.0             7
# 4     1489.0         4          1      2  11905135.0             4

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
regression=LinearRegression()
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
regression.coef_
# Out:
# array([ 3658013.84476706,  -671014.77587666, -1248577.00185212,
#          -65026.98285871,  1324014.61159837])

# %%
regression.intercept_
# Out:
# np.float64(11370987.675)

# %%
y_pred=regression.predict(X_test)

# %%
y_pred
# Out:
# array([12332102.64535362, 11387405.6388438 ,  6118222.93835294,
#        18770541.69707891, 14694690.10240307, 10419883.6074592 ,
#         9725428.85466031,  7598441.35763312, 16308476.16197572,
#        11264231.50773126])

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
mae=mean_absolute_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
rmse=np.sqrt(mse)
print("MAE:",mae)
print("MSE:",mse)   
print("RMSE:",rmse)
# Out:
# MAE: 3618524.070462787
# MSE: 25484392614740.43
# RMSE: 5048206.871230658

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)
print(score)
# Out:
# 0.39786939364548846
